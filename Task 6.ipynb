# %% [markdown]
# # Task 6

# %% [markdown]
# # 1.Matplotlib Basics

# %%
#Import the library:
import matplotlib.pyplot as plt

# %% [markdown]
# a. Line Plot

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.title('Line Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
#Interpretation: A simple line plot showing the trend in data.

# %% [markdown]
# b. Bar Plot:

# %%
categories = ['A', 'B', 'C']
values = [4, 7, 1]
plt.bar(categories, values)
plt.title('Bar Plot Example')
plt.show()

# %% [markdown]
# Interpretation: Displays comparisons among discrete categories.

# %% [markdown]
# c. Histogram

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.title('Histogram Example')
plt.show()

# %% [markdown]
# Interpretation: Shows distribution of data.

# %% [markdown]
# d. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# Interpretation: Displays relationship between two variables.

# %% [markdown]
# # 2. Seaborn Basics

# %%
#Import:
import seaborn as sns

# %% [markdown]
# a. Seaborn Lineplot

# %%
tips = sns.load_dataset('tips')
sns.lineplot(x='total_bill', y='tip', data=tips)
plt.title('Tip vs Total Bill')
plt.show()

# %% [markdown]
# Interpretation: Shows how tips vary with the total bill amount.

# %% [markdown]
# b. Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Boxplot: Total Bill by Day')
plt.show()

# %% [markdown]
# Interpretation: Useful for detecting outliers and understanding distribution per group.

# %% [markdown]
# c. Violin Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin Plot: Total Bill by Day')
plt.show()

# %% [markdown]
# Interpretation: Combines boxplot with KDE for more insight into distribution.

# %% [markdown]
# d. Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset("titanic")

# Select numerical features only
numeric_data = titanic.select_dtypes(include='number')

# Compute correlation matrix
corr_matrix = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title("Correlation Heatmap - Titanic Dataset")
plt.show()

# %% [markdown]
# Interpretation:
# 1.Fare is positively correlated with Pclass (negatively actually, since higher class = lower number).
#
# 2.Age and Parch show weak correlation, possibly due to family size effects.
#
# 3.Most features are weakly correlated, indicating a complex relationship in survival probability.
#
# 4.Helps identify which numerical features might influence each other in modeling.
